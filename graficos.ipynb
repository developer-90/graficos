# %% [markdown]
# # ACTIVIDAD 20

# %% [markdown]
# https://github.com/neo4j-contrib/northwind-neo4j

# %% [markdown]
# ## Muestra un gráfico de barras con el total de productos por categoria

# %%
import pandas as pd
import matplotlib.pyplot as plt

def consumir():
    datos = pd.read_csv('products.csv')
    df = datos[['unitsInStock','categoryID']] # convertir datos a dataframe
    valor_productos_categoria = df.groupby('categoryID')['unitsInStock'].mean()
    #valor_productos_categoria.head(5).plot.barh()
    df.plot.barh()
    plt.show()
consumir()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def consumir():
    datos = pd.read_csv('products.csv')
    df = datos[['unitPrice','categoryID']] # convertir datos a dataframe
    df.head(8).unitPrice.value_counts().plot.pie()
    plt.show()
consumir()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def consumir():
    datos = pd.read_csv('products.csv')
    df = datos[['unitPrice','categoryID']] # convertir datos a dataframe
    df.head(8).unitPrice.plot.hist()
    print(df.sample(5))
consumir()
# Out:
#     unitPrice  categoryID
# 53       7.45           6
# 39      18.40           8
# 38      18.00           1
# 10      21.00           4
# 50      53.00           7
